# %%
import pandas as pd

# %%
# put all the joined data frames into a dictionary for easy access

joined_dfs = {}

for year in range(2014, 2025):
    df = pd.read_csv(f'../Data/raw_data/{year}/join_df_{year}.csv')
    joined_dfs[year] = df

# %% [markdown]
# ### Each joined_df is the result of joining Institutional HR, Finance and Header Information

# %%
joined_dfs[2014].head()
# Out:
#    UNITID                               INSTNM  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100706  University of Alabama in Huntsville
# 3  100724             Alabama State University
# 4  100751            The University of Alabama
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                 301 Sparkman Dr  Huntsville     AL       35899     1
# 3            915 S Jackson Street  Montgomery     AL  36104-0271     1
# 4             739 University Blvd  Tuscaloosa     AL  35487-0166     1
#
#    OBEREG                   CHFNM   CHFTITLE  ... SFTEBFO  SFTECES  SFTECLAM  \
# 0       5  Dr. Andrew Hugine, Jr.  President  ...    35.0     36.0     124.0
# 1       5            Ray L. Watts  President  ...  1032.0   1360.0     311.0
# 2       5    Robert A. Altenkirch  President  ...    73.0    469.0      59.0
# 3       5               Gwen Boyd  President  ...    38.0     29.0      93.0
# 4       5    Dr. Judith L. Bonner  President  ...   414.0    434.0     491.0
#
#    SFTEHLTH SFTEOTHR SFTESRVC SFTESALE SFTEOFAS SFTENRCM SFTEPTMM
# 0       1.0      NaN     54.0      3.0    173.0      9.0     13.0
# 1     418.0      NaN    682.0      NaN   1266.0    303.0     85.0
# 2       3.0      NaN     87.0      NaN    190.0     28.0      1.0
# 3       4.0      NaN    146.0      8.0    122.0     39.0      9.0
# 4     206.0      NaN    719.0     27.0    849.0    209.0    118.0
#
# [5 rows x 416 columns]
